# %% [markdown]
# ### Need to execute proper line to get help for tab complition.

# %%
# Execute this cell to get the TAB help.
import os

# Hit tab to list down the functions. 
os.listdir()

# %% [markdown]
# ### Shell commands are prefixed with !

# %%
# !dir c:\ /b
# Out:
# Charts
# Dell
# Intel
# msdia80.dll
# My Web Sites
# nodejs
# PerfLogs
# Program Files
# Program Files (x86)
# Quarantine
# Shapes
# Sun
# Sweden
# SymCache
# temp
# tools
# Users
# WebSite.Downloads
# Windows

# %%
files = !dir c:\ /b

# %%
files
# Out:
# ['Charts',
#  'Dell',
#  'Intel',
#  'msdia80.dll',
#  'My Web Sites',
#  'nodejs',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'Quarantine',
#  'Shapes',
#  'Sun',
#  'Sweden',
#  'SymCache',
#  'temp',
#  'tools',
#  'Users',
#  'WebSite.Downloads',
#  'Windows']

# %% [markdown]
# ### _ is the last execution output

# %%
_
# Out:
# ['Charts',
#  'Dell',
#  'Intel',
#  'msdia80.dll',
#  'My Web Sites',
#  'nodejs',
#  'PerfLogs',
#  'Program Files',
#  'Program Files (x86)',
#  'Quarantine',
#  'Shapes',
#  'Sun',
#  'Sweden',
#  'SymCache',
#  'temp',
#  'tools',
#  'Users',
#  'WebSite.Downloads',
#  'Windows']

# %% [markdown]
# ### Using panda to visualize data

# %%
import pandas as pd

# %%
data = pd.read_csv('data/iris.txt')

# %%
data
# Out:
#      5.1  7.0   2.8  0.6      Iris-setosa
# 0    4.9  6.0   2.8  0.6      Iris-setosa
# 1    4.7  6.4   2.6  0.6      Iris-setosa
# 2    4.6  6.2   3.0  0.6      Iris-setosa
# 3    5.0  7.2   2.8  0.6      Iris-setosa
# 4    5.4  7.8   3.4  1.2      Iris-setosa
# 5    4.6  6.8   2.8  0.9      Iris-setosa
# 6    5.0  6.8   3.0  0.6      Iris-setosa
# 7    4.4  5.8   2.8  0.6      Iris-setosa
# 8    4.9  6.2   3.0  0.3      Iris-setosa
# 9    5.4  7.4   3.0  0.6      Iris-setosa
# 10   4.8  6.8   3.2  0.6      Iris-setosa
# 11   4.8  6.0   2.8  0.3      Iris-setosa
# 12   4.3  6.0   2.2  0.3      Iris-setosa
# 13   5.8  8.0   2.4  0.6      Iris-setosa
# 14   5.7  8.8   3.0  1.2      Iris-setosa
# 15   5.4  7.8   2.6  1.2      Iris-setosa
# 16   5.1  7.0   2.8  0.9      Iris-setosa
# 17   5.7  7.6   3.4  0.9      Iris-setosa
# 18   5.1  7.6   3.0  0.9      Iris-setosa
# 19   5.4  6.8   3.4  0.6      Iris-setosa
# 20   5.1  7.4   3.0  1.2      Iris-setosa
# ...

# %%
data.style.highlight_max()
# Out:
# <style  type="text/css" >
#     #T_642686d8_8c1d_11e8_a6fd_d481d7664c71row14_col1 {
#             background-color:  yellow;
#         }    #T_642686d8_8c1d_11e8_a6fd_d481d7664c71row99_col2 {
#             background-color:  yellow;
#         }    #T_642686d8_8c1d_11e8_a6fd_d481d7664c71row99_col3 {
#             background-color:  yellow;
#         }    #T_642686d8_8c1d_11e8_a6fd_d481d7664c71row101_col0 {
#             background-color:  yellow;
#         }</style>
# <table id="T_642686d8_8c1d_11e8_a6fd_d481d7664c71" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >5.1</th>
#         <th class="col_heading level0 col1" >7.0</th>
#         <th class="col_heading level0 col2" >2.8</th>
#         <th class="col_heading level0 col3" >0.6</th>
#         <th class="col_heading level0 col4" >Iris-setosa</th>
#     </tr></thead>
# <tbody>    <tr>
# ...

# %% [markdown]
# ### Show all the functions of a package

# %%
dir(pd)
# Out:
# ['Categorical',
#  'CategoricalIndex',
#  'DataFrame',
#  'DateOffset',
#  'DatetimeIndex',
#  'ExcelFile',
#  'ExcelWriter',
#  'Expr',
#  'Float64Index',
#  'Grouper',
#  'HDFStore',
#  'Index',
#  'IndexSlice',
#  'Int64Index',
#  'Interval',
#  'IntervalIndex',
#  'MultiIndex',
#  'NaT',
#  'Panel',
#  'Period',
#  'PeriodIndex',
#  'RangeIndex',
#  'Series',
#  'SparseArray',
#  'SparseDataFrame',
#  'SparseSeries',
#  'Term',
#  'TimeGrouper',
#  'Timedelta',
#  'TimedeltaIndex',
#  'Timestamp',
#  'UInt64Index',
#  'WidePanel',
#  '_DeprecatedModule',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__docformat__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_hashtable',
#  '_lib',
#  '_libs',
#  '_np_version_under1p10',
#  '_np_version_under1p11',
#  '_np_version_under1p12',
#  '_np_version_under1p13',
#  '_np_version_under1p14',
#  '_np_version_under1p15',
#  '_tslib',
#  '_version',
#  'api',
# ...

# %% [markdown]
# ### To show what an individual function do

# %%
pd.Index?
