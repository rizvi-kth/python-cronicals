# %% [markdown]
# #### Further inspect the veriables in the pycharm or spyder variable explorer. Spyder is best for Pandas data exploration

# %%
import pandas as pd
import numpy as np
import os
np_array = np.random.rand(3)
np_array
# Out:
# array([0.39595812, 0.64672497, 0.81876108])

# %%
type(np_array)
# Out:
# numpy.ndarray

# %% [markdown]
# ###  Introducing Panada Series

# %%
pd_series = pd.Series(np_array)
pd_series
# Out:
# 0    0.395958
# 1    0.646725
# 2    0.818761
# dtype: float64

# %%
pd_series = pd.Series(np_array,index = ["First","Second","third",])
pd_series
# Out:
# First     0.395958
# Second    0.646725
# third     0.818761
# dtype: float64

# %%
pd_series["First"]
# Out:
# 0.39595811915332

# %%
pd_series.index
# Out:
# Index(['First', 'Second', 'third'], dtype='object')

# %% [markdown]
# #### Data in to 2D

# %%
array2d = np.random.rand(3,2)
array2d
# Out:
# array([[0.62216539, 0.86213494],
#        [0.23255025, 0.18801175],
#        [0.81406405, 0.44017589]])

# %% [markdown]
# ### Introducing Pandas Dataframe

# %%
df = pd.DataFrame(array2d)
df
# Out:
#           0         1
# 0  0.622165  0.862135
# 1  0.232550  0.188012
# 2  0.814064  0.440176

# %%
df.columns = ["First", "Second"]
df
# Out:
#       First    Second
# 0  0.622165  0.862135
# 1  0.232550  0.188012
# 2  0.814064  0.440176

# %%
# !pwd
# Out:
# /c/Users/A547184/Git/Repos/python-cronicals/Python-Course/python-practice

# %%
# !ls
# Out:
# MyPackage
# beyond-basic.py
# collection-etc.ipynb
# package-etc.ipynb
# pandas-cronic.ipynb
# pandas-on-spyder

# %%
CSV_PATH = os.path.join("pandas-on-spyder" ,"TestData", "titanic.csv")

# Read just 5 rows to see what's there
#df = pd.read_csv(CSV_PATH, nrows=5)
df = pd.read_csv(CSV_PATH)

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.6+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df['Age'].min()
# Out:
# 0.42

# %% [markdown]
# ##### Slicing the DataFrame

# %%
# Last 10 rows
df[-10:]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %% [markdown]
# ##### iloc and loc is more efficient than Slicing in terms of performance

# %%
# With iloc you can set columns by integer
# With iloc you can set the index of the row
df.iloc[-5:, [0,3,2,4]]
# Out:
#      PassengerId                                      Name  Pclass     Sex
# 886          887                     Montvila, Rev. Juozas       2    male
# 887          888              Graham, Miss. Margaret Edith       1  female
# 888          889  Johnston, Miss. Catherine Helen "Carrie"       3  female
# 889          890                     Behr, Mr. Karl Howell       1    male
# 890          891                       Dooley, Mr. Patrick       3    male

# %%
# With loc you can set columns by column name
# With loc you can set row indexes of you set a column to be your indexed column
#df['PassengerId'] = df.index

dfr = pd.DataFrame(data = df, index = ['PassengerId'] )

dfr.loc[:, ['PassengerId','Name']]
# Out:
#              PassengerId Name
# PassengerId          NaN  NaN

# %%
# %matplotlib inline

# %%
df['Age'].plot()

# %%
df['Age'].plot.hist(bins=100)

# %% [markdown]
# ##### Transpose a pandas DataFrame

# %%
dft = df.head(5)
dft = dft.T
dft
# Out:
#                                    0  \
# PassengerId                        1
# Survived                           0
# Pclass                             3
# Name         Braund, Mr. Owen Harris
# Sex                             male
# Age                               22
# SibSp                              1
# Parch                              0
# Ticket                     A/5 21171
# Fare                            7.25
# Cabin                            NaN
# Embarked                           S
#
#                                                              1  \
# PassengerId                                                  2
# Survived                                                     1
# Pclass                                                       1
# Name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                     female
# Age                                                         38
# SibSp                                                        1
# Parch                                                        0
# Ticket                                                PC 17599
# Fare                                                   71.2833
# Cabin                                                      C85
# Embarked                                                     C
#
#                                   2  \
# PassengerId                       3
# Survived                          1
# Pclass                            3
# Name         Heikkinen, Miss. Laina
# Sex                          female
# Age                              26
# SibSp                             0
# Parch                             0
# Ticket             STON/O2. 3101282
# Fare                          7.925
# Cabin                           NaN
# Embarked                          S
#
#                                                         3  \
# PassengerId                                             4
# Survived                                                1
# Pclass                                                  1
# Name         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                                female
# Age                                                    35
# SibSp                                                   1
# Parch                                                   0
# Ticket                                             113803
# Fare                                                 53.1
# Cabin                                                C123
# Embarked                                                S
#
#                                     4
# PassengerId                         5
# Survived                            0
# Pclass                              3
# Name         Allen, Mr. William Henry
# Sex                              male
# Age                                35
# SibSp                               0
# Parch                               0
# Ticket                         373450
# Fare                             8.05
# Cabin                             NaN
# Embarked                            S

# %%
dft[0]
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                                 22
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 0, dtype: object

# %%
CSV_PATH = os.path.join("pandas-on-spyder" ,"TestData", "titanic.csv")
# Proper data loading
COLS_TO_USE = ['PassengerId','Survived', 'Pclass', 'Sex', 'Age', 'Fare', 'Cabin']
df = pd.read_csv(CSV_PATH, usecols=COLS_TO_USE, index_col='PassengerId')

df['Fare'].count()
df_prs = pd.to_numeric(df['Fare'], errors = "coerce")

# It has become a series
type(df_prs)
df_prs.count()
df_prs
# Apply iloc in a series
df_prs.iloc[260:270]
df_prs.iloc[263]
# Out:
# 0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 6 columns):
# Survived    891 non-null int64
# Pclass      891 non-null int64
# Sex         891 non-null object
# Age         714 non-null float64
# Fare        891 non-null float64
# Cabin       204 non-null object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 48.7+ KB

# %%
df_prs.plot(kind='bar')

# %% [markdown]
# ### Filtering in DataFrame

# %%
df['Age'] > 18

# %%
test_df =  pd.DataFrame(np.random.rand(3,2), index = ['fst', 'sec', 'thd'], columns = ['cow', 'dog'])

# %%
# Filtering the rows with a list 
# i.e. [ True, True, True, True, True .... the number of row]
test_df[[True, Flase, True]]
# Out:
#           cow       dog
# fst  0.562069  0.860661
# sec  0.247273  0.444996
# thd  0.933573  0.798852

# %%
# Filtering the rows with a list from an expression
# test_df['cow'] > 0.5 givs a list of True/Flase of row size.
test_df[test_df['cow'] > 0.5]
# Out:
#           cow       dog
# fst  0.562069  0.860661
# thd  0.933573  0.798852

# %%
# Filter out how many children died.
df[(df['Age'] < 18) & (df['Survived'] == 0)]
# Out:
#              Survived  Pclass     Sex   Age      Fare    Cabin
# PassengerId
# 8                   0       3    male   2.0   21.0750      NaN
# 15                  0       3  female  14.0    7.8542      NaN
# 17                  0       3    male   2.0   29.1250      NaN
# 25                  0       3  female   8.0   21.0750      NaN
# 51                  0       3    male   7.0   39.6875      NaN
# 60                  0       3    male  11.0   46.9000      NaN
# 64                  0       3    male   4.0   27.9000      NaN
# 72                  0       3  female  16.0   46.9000      NaN
# 87                  0       3    male  16.0   34.3750      NaN
# 112                 0       3  female  14.5   14.4542      NaN
# 115                 0       3  female  17.0   14.4583      NaN
# 120                 0       3  female   2.0   31.2750      NaN
# 139                 0       3    male  16.0    9.2167      NaN
# 148                 0       3  female   9.0   34.3750      NaN
# 164                 0       3    male  17.0    8.6625      NaN
# 165                 0       3    male   1.0   39.6875      NaN
# 172                 0       3    male   4.0   29.1250      NaN
# 183                 0       3    male   9.0   31.3875      NaN
# 206                 0       3  female   2.0   10.4625       G6
# 267                 0       3    male  16.0   39.6875      NaN
# 279                 0       3    male   7.0   29.1250      NaN
# 283                 0       3    male  16.0    9.5000      NaN
# 298                 0       1  female   2.0  151.5500  C22 C26
# 334                 0       3    male  16.0   18.0000      NaN
# 353                 0       3    male  15.0    7.2292      NaN
# 375                 0       3  female   3.0   21.0750      NaN
# 387                 0       3    male   1.0   46.9000      NaN
# 420                 0       3  female  10.0   24.1500      NaN
# 434                 0       3    male  17.0    7.1250      NaN
# 481                 0       3    male   9.0   46.9000      NaN
# 501                 0       3    male  17.0    8.6625      NaN
# 533                 0       3    male  17.0    7.2292      NaN
# 542                 0       3  female   9.0   31.2750      NaN
# 543                 0       3  female  11.0   31.2750      NaN
# 575                 0       3    male  16.0    8.0500      NaN
# 635                 0       3  female   9.0   27.9000      NaN
# 643                 0       3  female   2.0   27.9000      NaN
# 684                 0       3    male  14.0   46.9000      NaN
# 687                 0       3    male  14.0   39.6875      NaN
# 722                 0       3    male  17.0    7.0542      NaN
# 732                 0       3    male  11.0   18.7875      NaN
# 747                 0       3    male  16.0   20.2500      NaN
# 765                 0       3    male  16.0    7.7750      NaN
# 788                 0       3    male   8.0   29.1250      NaN
# 792                 0       2    male  16.0   26.0000      NaN
# 814                 0       3  female   6.0   31.2750      NaN
# 820                 0       3    male  10.0   27.9000      NaN
# 825                 0       3    male   2.0   39.6875      NaN
# 842                 0       2    male  16.0   10.5000      NaN
# 845                 0       3    male  17.0    8.6625      NaN
# 851                 0       3    male   4.0   31.2750      NaN
# 853                 0       3  female   9.0   15.2458      NaN

# %%
# Filter out how many children died - Using loc
df.loc[(df['Age']<18)&(df['Survived']==0),:]
# Out:
#              Survived  Pclass     Sex   Age      Fare    Cabin
# PassengerId
# 8                   0       3    male   2.0   21.0750      NaN
# 15                  0       3  female  14.0    7.8542      NaN
# 17                  0       3    male   2.0   29.1250      NaN
# 25                  0       3  female   8.0   21.0750      NaN
# 51                  0       3    male   7.0   39.6875      NaN
# 60                  0       3    male  11.0   46.9000      NaN
# 64                  0       3    male   4.0   27.9000      NaN
# 72                  0       3  female  16.0   46.9000      NaN
# 87                  0       3    male  16.0   34.3750      NaN
# 112                 0       3  female  14.5   14.4542      NaN
# 115                 0       3  female  17.0   14.4583      NaN
# 120                 0       3  female   2.0   31.2750      NaN
# 139                 0       3    male  16.0    9.2167      NaN
# 148                 0       3  female   9.0   34.3750      NaN
# 164                 0       3    male  17.0    8.6625      NaN
# 165                 0       3    male   1.0   39.6875      NaN
# 172                 0       3    male   4.0   29.1250      NaN
# 183                 0       3    male   9.0   31.3875      NaN
# 206                 0       3  female   2.0   10.4625       G6
# 267                 0       3    male  16.0   39.6875      NaN
# 279                 0       3    male   7.0   29.1250      NaN
# 283                 0       3    male  16.0    9.5000      NaN
# 298                 0       1  female   2.0  151.5500  C22 C26
# 334                 0       3    male  16.0   18.0000      NaN
# 353                 0       3    male  15.0    7.2292      NaN
# 375                 0       3  female   3.0   21.0750      NaN
# 387                 0       3    male   1.0   46.9000      NaN
# 420                 0       3  female  10.0   24.1500      NaN
# 434                 0       3    male  17.0    7.1250      NaN
# 481                 0       3    male   9.0   46.9000      NaN
# 501                 0       3    male  17.0    8.6625      NaN
# 533                 0       3    male  17.0    7.2292      NaN
# 542                 0       3  female   9.0   31.2750      NaN
# 543                 0       3  female  11.0   31.2750      NaN
# 575                 0       3    male  16.0    8.0500      NaN
# 635                 0       3  female   9.0   27.9000      NaN
# 643                 0       3  female   2.0   27.9000      NaN
# 684                 0       3    male  14.0   46.9000      NaN
# 687                 0       3    male  14.0   39.6875      NaN
# 722                 0       3    male  17.0    7.0542      NaN
# 732                 0       3    male  11.0   18.7875      NaN
# 747                 0       3    male  16.0   20.2500      NaN
# 765                 0       3    male  16.0    7.7750      NaN
# 788                 0       3    male   8.0   29.1250      NaN
# 792                 0       2    male  16.0   26.0000      NaN
# 814                 0       3  female   6.0   31.2750      NaN
# 820                 0       3    male  10.0   27.9000      NaN
# 825                 0       3    male   2.0   39.6875      NaN
# 842                 0       2    male  16.0   10.5000      NaN
# 845                 0       3    male  17.0    8.6625      NaN
# 851                 0       3    male   4.0   31.2750      NaN
# 853                 0       3  female   9.0   15.2458      NaN

# %% [markdown]
# #### Change/Modify column
