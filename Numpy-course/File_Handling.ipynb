# %%
import numpy as np

# %%
data = np.genfromtxt('data/iris.txt', delimiter=',',dtype=( float, float, float, float, '|U8'))
print(data)
# Out:
# [(5.1, 7. ,  2.8, 0.6, 'Iris-set') (4.9, 6. ,  2.8, 0.6, 'Iris-set')
#  (4.7, 6.4,  2.6, 0.6, 'Iris-set') (4.6, 6.2,  3. , 0.6, 'Iris-set')
#  (5. , 7.2,  2.8, 0.6, 'Iris-set') (5.4, 7.8,  3.4, 1.2, 'Iris-set')
#  (4.6, 6.8,  2.8, 0.9, 'Iris-set') (5. , 6.8,  3. , 0.6, 'Iris-set')
#  (4.4, 5.8,  2.8, 0.6, 'Iris-set') (4.9, 6.2,  3. , 0.3, 'Iris-set')
#  (5.4, 7.4,  3. , 0.6, 'Iris-set') (4.8, 6.8,  3.2, 0.6, 'Iris-set')
#  (4.8, 6. ,  2.8, 0.3, 'Iris-set') (4.3, 6. ,  2.2, 0.3, 'Iris-set')
#  (5.8, 8. ,  2.4, 0.6, 'Iris-set') (5.7, 8.8,  3. , 1.2, 'Iris-set')
#  (5.4, 7.8,  2.6, 1.2, 'Iris-set') (5.1, 7. ,  2.8, 0.9, 'Iris-set')
#  (5.7, 7.6,  3.4, 0.9, 'Iris-set') (5.1, 7.6,  3. , 0.9, 'Iris-set')
#  (5.4, 6.8,  3.4, 0.6, 'Iris-set') (5.1, 7.4,  3. , 1.2, 'Iris-set')
#  (4.6, 7.2,  2. , 0.6, 'Iris-set') (5.1, 6.6,  3.4, 1.5, 'Iris-set')
#  (4.8, 6.8,  3.8, 0.6, 'Iris-set') (5. , 6. ,  3.2, 0.6, 'Iris-set')
#  (5. , 6.8,  3.2, 1.2, 'Iris-set') (5.2, 7. ,  3. , 0.6, 'Iris-set')
#  (5.2, 6.8,  2.8, 0.6, 'Iris-set') (4.7, 6.4,  3.2, 0.6, 'Iris-set')
#  (4.8, 6.2,  3.2, 0.6, 'Iris-set') (5.4, 6.8,  3. , 1.2, 'Iris-set')
#  (5.2, 8.2,  3. , 0.3, 'Iris-set') (5.5, 8.4,  2.8, 0.6, 'Iris-set')
#  (4.9, 6.2,  3. , 0.3, 'Iris-set') (5. , 6.4,  2.4, 0.6, 'Iris-set')
#  (5.5, 7. ,  2.6, 0.6, 'Iris-set') (4.9, 6.2,  3. , 0.3, 'Iris-set')
#  (4.4, 6. ,  2.6, 0.6, 'Iris-set') (5.1, 6.8,  3. , 0.6, 'Iris-set')
#  (5. , 7. ,  2.6, 0.9, 'Iris-set') (4.5, 4.6,  2.6, 0.9, 'Iris-set')
#  (4.4, 6.4,  2.6, 0.6, 'Iris-set') (5. , 7. ,  3.2, 1.8, 'Iris-set')
#  (5.1, 7.6,  3.8, 1.2, 'Iris-set') (4.8, 6. ,  2.8, 0.9, 'Iris-set')
#  (5.1, 7.6,  3.2, 0.6, 'Iris-set') (4.6, 6.4,  2.8, 0.6, 'Iris-set')
#  (5.3, 7.4,  3. , 0.6, 'Iris-set') (5. , 6.6,  2.8, 0.6, 'Iris-set')
#  (7. , 6.4,  9.4, 4.2, 'Iris-ver') (6.4, 6.4,  9. , 4.5, 'Iris-ver')
#  (6.9, 6.2,  9.8, 4.5, 'Iris-ver') (5.5, 4.6,  8. , 3.9, 'Iris-ver')
#  (6.5, 5.6,  9.2, 4.5, 'Iris-ver') (5.7, 5.6,  9. , 3.9, 'Iris-ver')
#  (6.3, 6.6,  9.4, 4.8, 'Iris-ver') (4.9, 4.8,  6.6, 3. , 'Iris-ver')
#  (6.6, 5.8,  9.2, 3.9, 'Iris-ver') (5.2, 5.4,  7.8, 4.2, 'Iris-ver')
#  (5. , 4. ,  7. , 3. , 'Iris-ver') (5.9, 6. ,  8.4, 4.5, 'Iris-ver')
#  (6. , 4.4,  8. , 3. , 'Iris-ver') (6.1, 5.8,  9.4, 4.2, 'Iris-ver')
#  (5.6, 5.8,  7.2, 3.9, 'Iris-ver') (6.7, 6.2,  8.8, 4.2, 'Iris-ver')
#  (5.6, 6. ,  9. , 4.5, 'Iris-ver') (5.8, 5.4,  8.2, 3. , 'Iris-ver')
#  (6.2, 4.4,  9. , 4.5, 'Iris-ver') (5.6, 5. ,  7.8, 3.3, 'Iris-ver')
#  (5.9, 6.4,  9.6, 5.4, 'Iris-ver') (6.1, 5.6,  8. , 3.9, 'Iris-ver')
#  (6.3, 5. ,  9.8, 4.5, 'Iris-ver') (6.1, 5.6,  9.4, 3.6, 'Iris-ver')
#  (6.4, 5.8,  8.6, 3.9, 'Iris-ver') (6.6, 6. ,  8.8, 4.2, 'Iris-ver')
#  (6.8, 5.6,  9.6, 4.2, 'Iris-ver') (6.7, 6. , 10. , 5.1, 'Iris-ver')
#  (6. , 5.8,  9. , 4.5, 'Iris-ver') (5.7, 5.2,  7. , 3. , 'Iris-ver')
#  (5.5, 4.8,  7.6, 3.3, 'Iris-ver') (5.5, 4.8,  7.4, 3. , 'Iris-ver')
#  (5.8, 5.4,  7.8, 3.6, 'Iris-ver') (6. , 5.4, 10.2, 4.8, 'Iris-ver')
#  (5.4, 6. ,  9. , 4.5, 'Iris-ver') (6. , 6.8,  9. , 4.8, 'Iris-ver')
#  (6.7, 6.2,  9.4, 4.5, 'Iris-ver') (6.3, 4.6,  8.8, 3.9, 'Iris-ver')
#  (5.6, 6. ,  8.2, 3.9, 'Iris-ver') (5.5, 5. ,  8. , 3.9, 'Iris-ver')
#  (5.5, 5.2,  8.8, 3.6, 'Iris-ver') (6.1, 6. ,  9.2, 4.2, 'Iris-ver')
#  (5.8, 5.2,  8. , 3.6, 'Iris-ver') (5. , 4.6,  6.6, 3. , 'Iris-ver')
#  (5.6, 5.4,  8.4, 3.9, 'Iris-ver') (5.7, 6. ,  8.4, 3.6, 'Iris-ver')
#  (5.7, 5.8,  8.4, 3.9, 'Iris-ver') (6.2, 5.8,  8.6, 3.9, 'Iris-ver')
#  (5.1, 5. ,  6. , 3.3, 'Iris-ver') (5.7, 5.6,  8.2, 3.9, 'Iris-ver')
#  (6.3, 6.6, 12. , 7.5, 'Iris-vir') (5.8, 5.4, 10.2, 5.7, 'Iris-vir')
#  (7.1, 6. , 11.8, 6.3, 'Iris-vir') (6.3, 5.8, 11.2, 5.4, 'Iris-vir')
#  (6.5, 6. , 11.6, 6.6, 'Iris-vir')]

# %%
print('There are %i samples in the file' %data.shape[0])
# Out:
# There are 105 samples in the file

# %% [markdown]
# ### Iterate all the rows

# %%
for i in data:
    print('r = ', i)
# Out:
# r =  (5.1, 7., 2.8, 0.6, 'Iris-set')
# r =  (4.9, 6., 2.8, 0.6, 'Iris-set')
# r =  (4.7, 6.4, 2.6, 0.6, 'Iris-set')
# r =  (4.6, 6.2, 3., 0.6, 'Iris-set')
# r =  (5., 7.2, 2.8, 0.6, 'Iris-set')
# r =  (5.4, 7.8, 3.4, 1.2, 'Iris-set')
# r =  (4.6, 6.8, 2.8, 0.9, 'Iris-set')
# r =  (5., 6.8, 3., 0.6, 'Iris-set')
# r =  (4.4, 5.8, 2.8, 0.6, 'Iris-set')
# r =  (4.9, 6.2, 3., 0.3, 'Iris-set')
# r =  (5.4, 7.4, 3., 0.6, 'Iris-set')
# r =  (4.8, 6.8, 3.2, 0.6, 'Iris-set')
# r =  (4.8, 6., 2.8, 0.3, 'Iris-set')
# r =  (4.3, 6., 2.2, 0.3, 'Iris-set')
# r =  (5.8, 8., 2.4, 0.6, 'Iris-set')
# r =  (5.7, 8.8, 3., 1.2, 'Iris-set')
# r =  (5.4, 7.8, 2.6, 1.2, 'Iris-set')
# r =  (5.1, 7., 2.8, 0.9, 'Iris-set')
# r =  (5.7, 7.6, 3.4, 0.9, 'Iris-set')
# r =  (5.1, 7.6, 3., 0.9, 'Iris-set')
# r =  (5.4, 6.8, 3.4, 0.6, 'Iris-set')
# r =  (5.1, 7.4, 3., 1.2, 'Iris-set')
# r =  (4.6, 7.2, 2., 0.6, 'Iris-set')
# r =  (5.1, 6.6, 3.4, 1.5, 'Iris-set')
# r =  (4.8, 6.8, 3.8, 0.6, 'Iris-set')
# r =  (5., 6., 3.2, 0.6, 'Iris-set')
# r =  (5., 6.8, 3.2, 1.2, 'Iris-set')
# r =  (5.2, 7., 3., 0.6, 'Iris-set')
# r =  (5.2, 6.8, 2.8, 0.6, 'Iris-set')
# r =  (4.7, 6.4, 3.2, 0.6, 'Iris-set')
# r =  (4.8, 6.2, 3.2, 0.6, 'Iris-set')
# r =  (5.4, 6.8, 3., 1.2, 'Iris-set')
# r =  (5.2, 8.2, 3., 0.3, 'Iris-set')
# r =  (5.5, 8.4, 2.8, 0.6, 'Iris-set')
# r =  (4.9, 6.2, 3., 0.3, 'Iris-set')
# r =  (5., 6.4, 2.4, 0.6, 'Iris-set')
# r =  (5.5, 7., 2.6, 0.6, 'Iris-set')
# r =  (4.9, 6.2, 3., 0.3, 'Iris-set')
# r =  (4.4, 6., 2.6, 0.6, 'Iris-set')
# r =  (5.1, 6.8, 3., 0.6, 'Iris-set')
# r =  (5., 7., 2.6, 0.9, 'Iris-set')
# r =  (4.5, 4.6, 2.6, 0.9, 'Iris-set')
# r =  (4.4, 6.4, 2.6, 0.6, 'Iris-set')
# r =  (5., 7., 3.2, 1.8, 'Iris-set')
# r =  (5.1, 7.6, 3.8, 1.2, 'Iris-set')
# r =  (4.8, 6., 2.8, 0.9, 'Iris-set')
# r =  (5.1, 7.6, 3.2, 0.6, 'Iris-set')
# r =  (4.6, 6.4, 2.8, 0.6, 'Iris-set')
# r =  (5.3, 7.4, 3., 0.6, 'Iris-set')
# r =  (5., 6.6, 2.8, 0.6, 'Iris-set')
# r =  (7., 6.4, 9.4, 4.2, 'Iris-ver')
# r =  (6.4, 6.4, 9., 4.5, 'Iris-ver')
# r =  (6.9, 6.2, 9.8, 4.5, 'Iris-ver')
# r =  (5.5, 4.6, 8., 3.9, 'Iris-ver')
# r =  (6.5, 5.6, 9.2, 4.5, 'Iris-ver')
# r =  (5.7, 5.6, 9., 3.9, 'Iris-ver')
# r =  (6.3, 6.6, 9.4, 4.8, 'Iris-ver')
# r =  (4.9, 4.8, 6.6, 3., 'Iris-ver')
# r =  (6.6, 5.8, 9.2, 3.9, 'Iris-ver')
# r =  (5.2, 5.4, 7.8, 4.2, 'Iris-ver')
# r =  (5., 4., 7., 3., 'Iris-ver')
# r =  (5.9, 6., 8.4, 4.5, 'Iris-ver')
# r =  (6., 4.4, 8., 3., 'Iris-ver')
# r =  (6.1, 5.8, 9.4, 4.2, 'Iris-ver')
# r =  (5.6, 5.8, 7.2, 3.9, 'Iris-ver')
# r =  (6.7, 6.2, 8.8, 4.2, 'Iris-ver')
# r =  (5.6, 6., 9., 4.5, 'Iris-ver')
# r =  (5.8, 5.4, 8.2, 3., 'Iris-ver')
# r =  (6.2, 4.4, 9., 4.5, 'Iris-ver')
# r =  (5.6, 5., 7.8, 3.3, 'Iris-ver')
# r =  (5.9, 6.4, 9.6, 5.4, 'Iris-ver')
# r =  (6.1, 5.6, 8., 3.9, 'Iris-ver')
# r =  (6.3, 5., 9.8, 4.5, 'Iris-ver')
# r =  (6.1, 5.6, 9.4, 3.6, 'Iris-ver')
# r =  (6.4, 5.8, 8.6, 3.9, 'Iris-ver')
# r =  (6.6, 6., 8.8, 4.2, 'Iris-ver')
# r =  (6.8, 5.6, 9.6, 4.2, 'Iris-ver')
# r =  (6.7, 6., 10., 5.1, 'Iris-ver')
# r =  (6., 5.8, 9., 4.5, 'Iris-ver')
# r =  (5.7, 5.2, 7., 3., 'Iris-ver')
# r =  (5.5, 4.8, 7.6, 3.3, 'Iris-ver')
# r =  (5.5, 4.8, 7.4, 3., 'Iris-ver')
# r =  (5.8, 5.4, 7.8, 3.6, 'Iris-ver')
# r =  (6., 5.4, 10.2, 4.8, 'Iris-ver')
# r =  (5.4, 6., 9., 4.5, 'Iris-ver')
# r =  (6., 6.8, 9., 4.8, 'Iris-ver')
# r =  (6.7, 6.2, 9.4, 4.5, 'Iris-ver')
# r =  (6.3, 4.6, 8.8, 3.9, 'Iris-ver')
# r =  (5.6, 6., 8.2, 3.9, 'Iris-ver')
# r =  (5.5, 5., 8., 3.9, 'Iris-ver')
# r =  (5.5, 5.2, 8.8, 3.6, 'Iris-ver')
# r =  (6.1, 6., 9.2, 4.2, 'Iris-ver')
# r =  (5.8, 5.2, 8., 3.6, 'Iris-ver')
# r =  (5., 4.6, 6.6, 3., 'Iris-ver')
# r =  (5.6, 5.4, 8.4, 3.9, 'Iris-ver')
# r =  (5.7, 6., 8.4, 3.6, 'Iris-ver')
# r =  (5.7, 5.8, 8.4, 3.9, 'Iris-ver')
# r =  (6.2, 5.8, 8.6, 3.9, 'Iris-ver')
# r =  (5.1, 5., 6., 3.3, 'Iris-ver')
# r =  (5.7, 5.6, 8.2, 3.9, 'Iris-ver')
# r =  (6.3, 6.6, 12., 7.5, 'Iris-vir')
# r =  (5.8, 5.4, 10.2, 5.7, 'Iris-vir')
# r =  (7.1, 6., 11.8, 6.3, 'Iris-vir')
# r =  (6.3, 5.8, 11.2, 5.4, 'Iris-vir')
# r =  (6.5, 6., 11.6, 6.6, 'Iris-vir')

# %% [markdown]
# ### Get all the elements individually

# %%
for i in data.flatten():
    print('element = ', i)
# Out:
# element =  (5.1, 7., 2.8, 0.6, 'Iris-set')
# element =  (4.9, 6., 2.8, 0.6, 'Iris-set')
# element =  (4.7, 6.4, 2.6, 0.6, 'Iris-set')
# element =  (4.6, 6.2, 3., 0.6, 'Iris-set')
# element =  (5., 7.2, 2.8, 0.6, 'Iris-set')
# element =  (5.4, 7.8, 3.4, 1.2, 'Iris-set')
# element =  (4.6, 6.8, 2.8, 0.9, 'Iris-set')
# element =  (5., 6.8, 3., 0.6, 'Iris-set')
# element =  (4.4, 5.8, 2.8, 0.6, 'Iris-set')
# element =  (4.9, 6.2, 3., 0.3, 'Iris-set')
# element =  (5.4, 7.4, 3., 0.6, 'Iris-set')
# element =  (4.8, 6.8, 3.2, 0.6, 'Iris-set')
# element =  (4.8, 6., 2.8, 0.3, 'Iris-set')
# element =  (4.3, 6., 2.2, 0.3, 'Iris-set')
# element =  (5.8, 8., 2.4, 0.6, 'Iris-set')
# element =  (5.7, 8.8, 3., 1.2, 'Iris-set')
# element =  (5.4, 7.8, 2.6, 1.2, 'Iris-set')
# element =  (5.1, 7., 2.8, 0.9, 'Iris-set')
# element =  (5.7, 7.6, 3.4, 0.9, 'Iris-set')
# element =  (5.1, 7.6, 3., 0.9, 'Iris-set')
# element =  (5.4, 6.8, 3.4, 0.6, 'Iris-set')
# element =  (5.1, 7.4, 3., 1.2, 'Iris-set')
# element =  (4.6, 7.2, 2., 0.6, 'Iris-set')
# element =  (5.1, 6.6, 3.4, 1.5, 'Iris-set')
# element =  (4.8, 6.8, 3.8, 0.6, 'Iris-set')
# element =  (5., 6., 3.2, 0.6, 'Iris-set')
# element =  (5., 6.8, 3.2, 1.2, 'Iris-set')
# element =  (5.2, 7., 3., 0.6, 'Iris-set')
# element =  (5.2, 6.8, 2.8, 0.6, 'Iris-set')
# element =  (4.7, 6.4, 3.2, 0.6, 'Iris-set')
# element =  (4.8, 6.2, 3.2, 0.6, 'Iris-set')
# element =  (5.4, 6.8, 3., 1.2, 'Iris-set')
# element =  (5.2, 8.2, 3., 0.3, 'Iris-set')
# element =  (5.5, 8.4, 2.8, 0.6, 'Iris-set')
# element =  (4.9, 6.2, 3., 0.3, 'Iris-set')
# element =  (5., 6.4, 2.4, 0.6, 'Iris-set')
# element =  (5.5, 7., 2.6, 0.6, 'Iris-set')
# element =  (4.9, 6.2, 3., 0.3, 'Iris-set')
# element =  (4.4, 6., 2.6, 0.6, 'Iris-set')
# element =  (5.1, 6.8, 3., 0.6, 'Iris-set')
# element =  (5., 7., 2.6, 0.9, 'Iris-set')
# element =  (4.5, 4.6, 2.6, 0.9, 'Iris-set')
# element =  (4.4, 6.4, 2.6, 0.6, 'Iris-set')
# element =  (5., 7., 3.2, 1.8, 'Iris-set')
# element =  (5.1, 7.6, 3.8, 1.2, 'Iris-set')
# element =  (4.8, 6., 2.8, 0.9, 'Iris-set')
# element =  (5.1, 7.6, 3.2, 0.6, 'Iris-set')
# element =  (4.6, 6.4, 2.8, 0.6, 'Iris-set')
# element =  (5.3, 7.4, 3., 0.6, 'Iris-set')
# element =  (5., 6.6, 2.8, 0.6, 'Iris-set')
# element =  (7., 6.4, 9.4, 4.2, 'Iris-ver')
# element =  (6.4, 6.4, 9., 4.5, 'Iris-ver')
# element =  (6.9, 6.2, 9.8, 4.5, 'Iris-ver')
# element =  (5.5, 4.6, 8., 3.9, 'Iris-ver')
# element =  (6.5, 5.6, 9.2, 4.5, 'Iris-ver')
# element =  (5.7, 5.6, 9., 3.9, 'Iris-ver')
# element =  (6.3, 6.6, 9.4, 4.8, 'Iris-ver')
# element =  (4.9, 4.8, 6.6, 3., 'Iris-ver')
# element =  (6.6, 5.8, 9.2, 3.9, 'Iris-ver')
# element =  (5.2, 5.4, 7.8, 4.2, 'Iris-ver')
# element =  (5., 4., 7., 3., 'Iris-ver')
# element =  (5.9, 6., 8.4, 4.5, 'Iris-ver')
# element =  (6., 4.4, 8., 3., 'Iris-ver')
# element =  (6.1, 5.8, 9.4, 4.2, 'Iris-ver')
# element =  (5.6, 5.8, 7.2, 3.9, 'Iris-ver')
# element =  (6.7, 6.2, 8.8, 4.2, 'Iris-ver')
# element =  (5.6, 6., 9., 4.5, 'Iris-ver')
# element =  (5.8, 5.4, 8.2, 3., 'Iris-ver')
# element =  (6.2, 4.4, 9., 4.5, 'Iris-ver')
# element =  (5.6, 5., 7.8, 3.3, 'Iris-ver')
# element =  (5.9, 6.4, 9.6, 5.4, 'Iris-ver')
# element =  (6.1, 5.6, 8., 3.9, 'Iris-ver')
# element =  (6.3, 5., 9.8, 4.5, 'Iris-ver')
# element =  (6.1, 5.6, 9.4, 3.6, 'Iris-ver')
# element =  (6.4, 5.8, 8.6, 3.9, 'Iris-ver')
# element =  (6.6, 6., 8.8, 4.2, 'Iris-ver')
# element =  (6.8, 5.6, 9.6, 4.2, 'Iris-ver')
# element =  (6.7, 6., 10., 5.1, 'Iris-ver')
# element =  (6., 5.8, 9., 4.5, 'Iris-ver')
# element =  (5.7, 5.2, 7., 3., 'Iris-ver')
# element =  (5.5, 4.8, 7.6, 3.3, 'Iris-ver')
# element =  (5.5, 4.8, 7.4, 3., 'Iris-ver')
# element =  (5.8, 5.4, 7.8, 3.6, 'Iris-ver')
# element =  (6., 5.4, 10.2, 4.8, 'Iris-ver')
# element =  (5.4, 6., 9., 4.5, 'Iris-ver')
# element =  (6., 6.8, 9., 4.8, 'Iris-ver')
# element =  (6.7, 6.2, 9.4, 4.5, 'Iris-ver')
# element =  (6.3, 4.6, 8.8, 3.9, 'Iris-ver')
# element =  (5.6, 6., 8.2, 3.9, 'Iris-ver')
# element =  (5.5, 5., 8., 3.9, 'Iris-ver')
# element =  (5.5, 5.2, 8.8, 3.6, 'Iris-ver')
# element =  (6.1, 6., 9.2, 4.2, 'Iris-ver')
# element =  (5.8, 5.2, 8., 3.6, 'Iris-ver')
# element =  (5., 4.6, 6.6, 3., 'Iris-ver')
# element =  (5.6, 5.4, 8.4, 3.9, 'Iris-ver')
# element =  (5.7, 6., 8.4, 3.6, 'Iris-ver')
# element =  (5.7, 5.8, 8.4, 3.9, 'Iris-ver')
# element =  (6.2, 5.8, 8.6, 3.9, 'Iris-ver')
# element =  (5.1, 5., 6., 3.3, 'Iris-ver')
# element =  (5.7, 5.6, 8.2, 3.9, 'Iris-ver')
# element =  (6.3, 6.6, 12., 7.5, 'Iris-vir')
# element =  (5.8, 5.4, 10.2, 5.7, 'Iris-vir')
# element =  (7.1, 6., 11.8, 6.3, 'Iris-vir')
# element =  (6.3, 5.8, 11.2, 5.4, 'Iris-vir')
# element =  (6.5, 6., 11.6, 6.6, 'Iris-vir')

# %%
p1 = np.hsplit(data, 5)
print(p1)
# Out:
# [array([(5.1, 7. , 2.8, 0.6, 'Iris-set'), (4.9, 6. , 2.8, 0.6, 'Iris-set'),
#        (4.7, 6.4, 2.6, 0.6, 'Iris-set'), (4.6, 6.2, 3. , 0.6, 'Iris-set'),
#        (5. , 7.2, 2.8, 0.6, 'Iris-set'), (5.4, 7.8, 3.4, 1.2, 'Iris-set'),
#        (4.6, 6.8, 2.8, 0.9, 'Iris-set'), (5. , 6.8, 3. , 0.6, 'Iris-set'),
#        (4.4, 5.8, 2.8, 0.6, 'Iris-set'), (4.9, 6.2, 3. , 0.3, 'Iris-set'),
#        (5.4, 7.4, 3. , 0.6, 'Iris-set'), (4.8, 6.8, 3.2, 0.6, 'Iris-set'),
#        (4.8, 6. , 2.8, 0.3, 'Iris-set'), (4.3, 6. , 2.2, 0.3, 'Iris-set'),
#        (5.8, 8. , 2.4, 0.6, 'Iris-set'), (5.7, 8.8, 3. , 1.2, 'Iris-set'),
#        (5.4, 7.8, 2.6, 1.2, 'Iris-set'), (5.1, 7. , 2.8, 0.9, 'Iris-set'),
#        (5.7, 7.6, 3.4, 0.9, 'Iris-set'), (5.1, 7.6, 3. , 0.9, 'Iris-set'),
#        (5.4, 6.8, 3.4, 0.6, 'Iris-set')],
#       dtype=[('f0', '<f8'), ('f1', '<f8'), ('f2', '<f8'), ('f3', '<f8'), ('f4', '<U8')]), array([(5.1, 7.4, 3. , 1.2, 'Iris-set'), (4.6, 7.2, 2. , 0.6, 'Iris-set'),
#        (5.1, 6.6, 3.4, 1.5, 'Iris-set'), (4.8, 6.8, 3.8, 0.6, 'Iris-set'),
#        (5. , 6. , 3.2, 0.6, 'Iris-set'), (5. , 6.8, 3.2, 1.2, 'Iris-set'),
#        (5.2, 7. , 3. , 0.6, 'Iris-set'), (5.2, 6.8, 2.8, 0.6, 'Iris-set'),
#        (4.7, 6.4, 3.2, 0.6, 'Iris-set'), (4.8, 6.2, 3.2, 0.6, 'Iris-set'),
#        (5.4, 6.8, 3. , 1.2, 'Iris-set'), (5.2, 8.2, 3. , 0.3, 'Iris-set'),
#        (5.5, 8.4, 2.8, 0.6, 'Iris-set'), (4.9, 6.2, 3. , 0.3, 'Iris-set'),
#        (5. , 6.4, 2.4, 0.6, 'Iris-set'), (5.5, 7. , 2.6, 0.6, 'Iris-set'),
#        (4.9, 6.2, 3. , 0.3, 'Iris-set'), (4.4, 6. , 2.6, 0.6, 'Iris-set'),
#        (5.1, 6.8, 3. , 0.6, 'Iris-set'), (5. , 7. , 2.6, 0.9, 'Iris-set'),
#        (4.5, 4.6, 2.6, 0.9, 'Iris-set')],
#       dtype=[('f0', '<f8'), ('f1', '<f8'), ('f2', '<f8'), ('f3', '<f8'), ('f4', '<U8')]), array([(4.4, 6.4, 2.6, 0.6, 'Iris-set'), (5. , 7. , 3.2, 1.8, 'Iris-set'),
#        (5.1, 7.6, 3.8, 1.2, 'Iris-set'), (4.8, 6. , 2.8, 0.9, 'Iris-set'),
#        (5.1, 7.6, 3.2, 0.6, 'Iris-set'), (4.6, 6.4, 2.8, 0.6, 'Iris-set'),
#        (5.3, 7.4, 3. , 0.6, 'Iris-set'), (5. , 6.6, 2.8, 0.6, 'Iris-set'),
#        (7. , 6.4, 9.4, 4.2, 'Iris-ver'), (6.4, 6.4, 9. , 4.5, 'Iris-ver'),
#        (6.9, 6.2, 9.8, 4.5, 'Iris-ver'), (5.5, 4.6, 8. , 3.9, 'Iris-ver'),
#        (6.5, 5.6, 9.2, 4.5, 'Iris-ver'), (5.7, 5.6, 9. , 3.9, 'Iris-ver'),
#        (6.3, 6.6, 9.4, 4.8, 'Iris-ver'), (4.9, 4.8, 6.6, 3. , 'Iris-ver'),
#        (6.6, 5.8, 9.2, 3.9, 'Iris-ver'), (5.2, 5.4, 7.8, 4.2, 'Iris-ver'),
#        (5. , 4. , 7. , 3. , 'Iris-ver'), (5.9, 6. , 8.4, 4.5, 'Iris-ver'),
#        (6. , 4.4, 8. , 3. , 'Iris-ver')],
#       dtype=[('f0', '<f8'), ('f1', '<f8'), ('f2', '<f8'), ('f3', '<f8'), ('f4', '<U8')]), array([(6.1, 5.8,  9.4, 4.2, 'Iris-ver'),
#        (5.6, 5.8,  7.2, 3.9, 'Iris-ver'),
#        (6.7, 6.2,  8.8, 4.2, 'Iris-ver'),
#        (5.6, 6. ,  9. , 4.5, 'Iris-ver'),
#        (5.8, 5.4,  8.2, 3. , 'Iris-ver'),
#        (6.2, 4.4,  9. , 4.5, 'Iris-ver'),
#        (5.6, 5. ,  7.8, 3.3, 'Iris-ver'),
#        (5.9, 6.4,  9.6, 5.4, 'Iris-ver'),
#        (6.1, 5.6,  8. , 3.9, 'Iris-ver'),
#        (6.3, 5. ,  9.8, 4.5, 'Iris-ver'),
#        (6.1, 5.6,  9.4, 3.6, 'Iris-ver'),
#        (6.4, 5.8,  8.6, 3.9, 'Iris-ver'),
#        (6.6, 6. ,  8.8, 4.2, 'Iris-ver'),
#        (6.8, 5.6,  9.6, 4.2, 'Iris-ver'),
#        (6.7, 6. , 10. , 5.1, 'Iris-ver'),
#        (6. , 5.8,  9. , 4.5, 'Iris-ver'),
#        (5.7, 5.2,  7. , 3. , 'Iris-ver'),
#        (5.5, 4.8,  7.6, 3.3, 'Iris-ver'),
#        (5.5, 4.8,  7.4, 3. , 'Iris-ver'),
#        (5.8, 5.4,  7.8, 3.6, 'Iris-ver'),
#        (6. , 5.4, 10.2, 4.8, 'Iris-ver')],
#       dtype=[('f0', '<f8'), ('f1', '<f8'), ('f2', '<f8'), ('f3', '<f8'), ('f4', '<U8')]), array([(5.4, 6. ,  9. , 4.5, 'Iris-ver'),
#        (6. , 6.8,  9. , 4.8, 'Iris-ver'),
#        (6.7, 6.2,  9.4, 4.5, 'Iris-ver'),
#        (6.3, 4.6,  8.8, 3.9, 'Iris-ver'),
#        (5.6, 6. ,  8.2, 3.9, 'Iris-ver'),
#        (5.5, 5. ,  8. , 3.9, 'Iris-ver'),
#        (5.5, 5.2,  8.8, 3.6, 'Iris-ver'),
#        (6.1, 6. ,  9.2, 4.2, 'Iris-ver'),
#        (5.8, 5.2,  8. , 3.6, 'Iris-ver'),
#        (5. , 4.6,  6.6, 3. , 'Iris-ver'),
#        (5.6, 5.4,  8.4, 3.9, 'Iris-ver'),
#        (5.7, 6. ,  8.4, 3.6, 'Iris-ver'),
#        (5.7, 5.8,  8.4, 3.9, 'Iris-ver'),
#        (6.2, 5.8,  8.6, 3.9, 'Iris-ver'),
#        (5.1, 5. ,  6. , 3.3, 'Iris-ver'),
#        (5.7, 5.6,  8.2, 3.9, 'Iris-ver'),
#        (6.3, 6.6, 12. , 7.5, 'Iris-vir'),
#        (5.8, 5.4, 10.2, 5.7, 'Iris-vir'),
#        (7.1, 6. , 11.8, 6.3, 'Iris-vir'),
#        (6.3, 5.8, 11.2, 5.4, 'Iris-vir'),
#        (6.5, 6. , 11.6, 6.6, 'Iris-vir')],
#       dtype=[('f0', '<f8'), ('f1', '<f8'), ('f2', '<f8'), ('f3', '<f8'), ('f4', '<U8')])]

# %% [markdown]
# ### Find the python installation path

# %%
# Out:
# C:\ProgramData\Anaconda3\python.exe

# %%
p2
